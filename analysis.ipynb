# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('fulltableco2.csv')
df
# Out:
#           Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0     Afghanistan                AFG  2000      1.047128      0.003664
# 1     Afghanistan                AFG  2001      1.069098      0.069616
# 2     Afghanistan                AFG  2002      1.340995      0.055109
# 3     Afghanistan                AFG  2003      1.559602      0.091813
# 4     Afghanistan                AFG  2004      1.237247      0.091600
# ...           ...                ...   ...           ...           ...
# 5099       Global                WLD  2017  36096.739276  14506.973805
# 5100       Global                WLD  2018  36826.506600  14746.830688
# 5101       Global                WLD  2019  37082.558969  14725.978025
# 5102       Global                WLD  2020  35264.085734  14174.564010
# 5103       Global                WLD  2021  37123.850352  14979.598083
#
#                Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
rus = df[df['Country'] == 'Russia']
lines = rus.plot.line(x='Year', y='Total')

# %%
usa = df[df['Country'] == 'USA']
lines = usa.plot.line(x='Year', y='Total')

# %%
world = df[df['Country'] == 'Global']
lines = world.plot.line(x='Year', y='Total')

# %%
mostrecent = df[df['Year'] == 2021]
mostrecent.groupby('Country')['Total'].min().sort_values()
# Out:
# Country
# French Equatorial Africa        0.000000
# Ryukyu Islands                  0.000000
# Kuwaiti Oil Fires               0.000000
# St. Kitts-Nevis-Anguilla        0.000000
# Panama Canal Zone               0.000000
#                                 ...
# Russia                       1755.547390
# India                        2709.683625
# USA                          5007.335889
# China                       11472.369171
# Global                      37123.850352
# Name: Total, Length: 232, dtype: float64
